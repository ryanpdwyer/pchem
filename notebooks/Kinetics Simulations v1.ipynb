# %%
import matplotlib.pyplot as plt

import numpy as np
from scipy import integrate

# %% [markdown]
# ## Kinetics simulations
#
# E + S ⇌ ES ⇌ E + P
#
# Rate constants are $k_\text{f}, k_\text{r}, k_\text{cat}$

# %%
class NanoPrism:
    def __init__(self, Gface):
        retur

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
bottom = np.c_[[0, 0, 1], [0, 1, 1], [0, 0, 0]]
top = np.c_[[0, 0, 1], [0, 1, 1], [1, 1, 1]]


ax = plt.figure().add_subplot(projection='3d')

# bottom pts...
ax.plot_trisurf(top_bottom[0], top_bottom[1], top_bottom[2], linewidth=0.2, antialiased=True)
ax.set_axis_off()
ax
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/zn/x8ct2v5d1z714b45ycxv1hhc0000gn/T/ipykernel_42471/1707022952.py in <module>
#       7
#       8 # bottom pts...
# ----> 9 ax.plot_trisurf(top_bottom[0], top_bottom[1], top_bottom[2], linewidth=0.2, antialiased=True)
#      10 ax.set_axis_off()
#      11 ax
#
# ~/miniconda3/lib/python3.9/site-packages/mpl_toolkits/mplot3d/axes3d.py in plot_trisurf(self, color, norm, vmin, vmax, lightsource, *args, **kwargs)
#    2038
#    2039         tri, args, kwargs = \
# -> 2040             Triangulation.get_from_args_and_kwargs(*args, **kwargs)
#    2041         try:
#    2042             z = kwargs.pop('Z')
#
# ~/miniconda3/lib/python3.9/site-packages/matplotlib/tri/triangulation.py in get_from_args_and_kwargs(*args, **kwargs)
#     162             mask = kwargs.pop('mask', None)
#     163
# --> 164             triangulation = Triangulation(x, y, triangles, mask)
#     165         return triangulation, args, kwargs
#     166
#
# ~/miniconda3/lib/python3.9/site-packages/matplotlib/tri/triangulation.py in __init__(self, x, y, triangles, mask)
#      52             # No triangulation specified, so use matplotlib._qhull to obtain
#      53             # Delaunay triangulation.
# ---> 54             self.triangles, self._neighbors = _qhull.delaunay(x, y)
#      55             self.is_delaunay = True
#      56         else:
#
# ValueError: x and y arrays must consist of at least 3 unique points

# %%
from scipy.spatial import Delaunay

# %%
top_bottom = np.r_[bottom, top]
tris = Delaunay(top_bottom)

# %%
from scipy.spatial import ConvexHull
from munch import Munch

# %%
def prism(s, h, offset=0):
    pts = np.array([
        [0, 0, 0],
        [s/2, s*np.sqrt(3)/2, 0],
        [-s/2, s*np.sqrt(3)/2, 0],
        [0, 0, h],
        [-s/2, s*np.sqrt(3)/2, h],
        [s/2, s*np.sqrt(3)/2, h],
        ])
    x, y, z = pts.T
    z = z + offset
    ch = ConvexHull(pts)
    return Munch(x=x, y=y, z=z, triangles=ch.simplices)

# %%
out = prism(5, 0.2, -0.3)
out2 = prism(2, 0.2)

# %%
ax = plt.figure().add_subplot(projection='3d')
ax.plot_trisurf(out.x, out.y, out.z, triangles=out.triangles, linewidth=0.2, antialiased=True)
# ax.plot_trisurf(out2.x, out2.y, out2.z, triangles=out2.triangles, linewidth=0.2, antialiased=True)

ax
# Out:
# <Axes3DSubplot:>

# %%
Delaunay()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/zn/x8ct2v5d1z714b45ycxv1hhc0000gn/T/ipykernel_42471/1323952594.py in <module>
# ----> 1 Delaunay()
#
# qhull.pyx in scipy.spatial.qhull.Delaunay.__init__()
#
# TypeError: __init__() takes at least 2 positional arguments (1 given)

# %%
class Enzyme:
    def __init__(self, kf, kr, kcat):
        self.kf = kf
        self.kr = kr
        self.kcat = kcat
    
    def dydt(self, y, t):
        """State vector is S, E, ES, P"""
        kf, kr, kcat = self.kf, self.kr, self.kcat
        r1fwd = kf*y[0]*y[1]
        r1rev = kr * y[2]
        r2fwd = kcat * y[2]
        return np.array([
            -r1fwd + r1rev,
            -r1fwd + r1rev + r2fwd,
            r1fwd - r1rev - r2fwd,
            r2fwd
        ])
    
    def rate(self, y):
        return self.kcat * y.T[2]

# %%
e = Enzyme(1, 1, 1)
y0 = np.array([1, 0.1, 0, 0])
t= np.linspace(0, 1000, 1001)
out = integrate.odeint(e.dydt, y0, t)

# %%
out.shape
t.shape
# Out:
# (1001,)

# %%
 e.rate(out)
# Out:
# array([ 0.00000000e+00,  3.07301763e-02,  3.15460460e-02, ...,
#        -6.45994816e-12, -6.40791137e-12, -6.35546167e-12])

# %%
plt.plot(out[:, 0], e.rate(out), '.')
